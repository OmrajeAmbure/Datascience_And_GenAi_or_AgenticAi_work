# %% [markdown]
# # Tokenization
# **Tokenization is the process of breaking text into smaller units called tokens, which helps machines process and analyze language effectively.**
# - Tokens can be words, characters, or sub-words
# - Makes text easier for models to understand and process
# - Helps convert unstructured text into a structured format
# - Used in most NLP tasks like classification, translation and search

# %% [markdown]
# ![Alternative Text](https://media.geeksforgeeks.org/wp-content/uploads/20260428150900063629/Hello_Geeks_how_are_you.webp)
# ![Approch OF NLP](https://media.geeksforgeeks.org/wp-content/uploads/20260428150956926895/Popular_Approaches_of_Tokenization.webp)

# %% [markdown]
# ### Types OF Tokenizations
# !['Types OF Tokenizations'](https://media.geeksforgeeks.org/wp-content/uploads/20260428150930832396/Types_of_Tokenization_in_NLP.webp)
# !['Example'](https://media.geeksforgeeks.org/wp-content/uploads/20260428150835746423/Types_of_Tokenization.webp)

# %% [markdown]
# - **Word Tokenization:** This is the most common method where text is divided into individual words. It works well for languages with clear word boundaries, like English.
# - **Character Tokenization:** In this method, text is split into individual characters. This is particularly useful for languages without clear word boundaries or for tasks that require a detailed analysis, such as spelling correction.
# - **Sub-word Tokenization:** Sub-word tokenization strikes a balance between word and character tokenization by breaking down text into units that are larger than a single character but smaller than a full word.
# - **Sentence Tokenization:** Sentence tokenization is also a common technique used to make a division of paragraphs or large set of sentences into separated sentences as tokens.
# - **N-gram Tokenization:** N-gram tokenization splits words into fixed-sized chunks (size = n) of data.

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

# %%
text = """This is the most common method where text is divided into individual words. It works well for languages with clear word boundaries, like English."""

# %%
word_res_token = word_tokenize(text)
print(word_res_token)
# Out:
# ['This', 'is', 'the', 'most', 'common', 'method', 'where', 'text', 'is', 'divided', 'into', 'individual', 'words', '.', 'It', 'works', 'well', 'for', 'languages', 'with', 'clear', 'word', 'boundaries', ',', 'like', 'English', '.']

# %%
sentance_res_token = sent_tokenize(text)
print(sentance_res_token)
# Out:
# ['This is the most common method where text is divided into individual words.', 'It works well for languages with clear word boundaries, like English.']

# %%
word_tokens = list(text)
print(word_tokens)
# Out:
# ['T', 'h', 'i', 's', ' ', 'i', 's', ' ', 't', 'h', 'e', ' ', 'm', 'o', 's', 't', ' ', 'c', 'o', 'm', 'm', 'o', 'n', ' ', 'm', 'e', 't', 'h', 'o', 'd', ' ', 'w', 'h', 'e', 'r', 'e', ' ', 't', 'e', 'x', 't', ' ', 'i', 's', ' ', 'd', 'i', 'v', 'i', 'd', 'e', 'd', ' ', 'i', 'n', 't', 'o', ' ', 'i', 'n', 'd', 'i', 'v', 'i', 'd', 'u', 'a', 'l', ' ', 'w', 'o', 'r', 'd', 's', '.', ' ', 'I', 't', ' ', 'w', 'o', 'r', 'k', 's', ' ', 'w', 'e', 'l', 'l', ' ', 'f', 'o', 'r', ' ', 'l', 'a', 'n', 'g', 'u', 'a', 'g', 'e', 's', ' ', 'w', 'i', 't', 'h', ' ', 'c', 'l', 'e', 'a', 'r', ' ', 'w', 'o', 'r', 'd', ' ', 'b', 'o', 'u', 'n', 'd', 'a', 'r', 'i', 'e', 's', ',', ' ', 'l', 'i', 'k', 'e', ' ', 'E', 'n', 'g', 'l', 'i', 's', 'h', '.']

# %% [markdown]
# **1. WordPunctTokenizer**
# - It Splits text into alphabetic and non-alphabetic characters,
#
# - Separates all sequences of word characters and punctuation into tokens.
# - Especially splits contractions (Don't becomes Don, ', t).
# - Splits E-mails into E, -, mails.

# %%
from nltk.tokenize import WordPunctTokenizer

tokenizer = WordPunctTokenizer()
tokens = tokenizer.tokenize(
    "Don't split contractions. E-mails: hello@example.com!")
print(tokens)
# Out:
# ['Don', "'", 't', 'split', 'contractions', '.', 'E', '-', 'mails', ':', 'hello', '@', 'example', '.', 'com', '!']

# %% [markdown]
# **2. TreebankWordTokenizer**
# - It is suitable for linguistic analysis, handles punctuation and contractions.
#     - Mimics Penn Treebank-style tokenization, which is commonly used for NLP linguistic analysis.
#     - Handles certain English grammatical structures more “intelligently.”

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()
tokens = tokenizer.tokenize("Have a look at NLTK's tokenizers.")
print(tokens)
# Out:
# ['Have', 'a', 'look', 'at', 'NLTK', "'s", 'tokenizers', '.']

# %% [markdown]
# **3. Regex Tokenizer**
# - It customize pattern-based splitting.
#     - Tokenizes based on a regular expression pattern.
#     - \w+ matches words and numbers, omitting punctuation completely.

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(
    "Custom rule: keep only words & numbers, drop punctuation!")
print(tokens)
# Out:
# ['Custom', 'rule', 'keep', 'only', 'words', 'numbers', 'drop', 'punctuation']

# %% [markdown]
# **Another has Advance Topic We studied in Transformer**

# %% [markdown]
# # Removing stop words with NLTK in Python

# %% [markdown]
# ![StopWordRemoval](https://media.geeksforgeeks.org/wp-content/uploads/20260714093545935874/consider_the_sentence_the_quick_brown_fox_jumps_over_the_lazy_dog_.webp)

# %% [markdown]
# ### Categories of Stopwords
# - Understanding different types of stopwords helps in making informed decisions:
#     - Standard Stopwords: Common function words like articles ("a", "the"), conjunctions ("and", "but") and prepositions ("in", "on")
#     - Domain-Specific Stopwords: Context-dependent terms that appear frequently in specific fields like "patient" in medical texts
#     - Contextual Stopwords: Words with extremely high frequency in particular datasets
#     - Numerical Stopwords: Digits, punctuation marks and single characters

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# **nltk.download('stopwords')**
# - This downloads the stopwords corpus.
# - [the,
# is,
# am,
# are,
# was,
# were,
# a,
# an,
# of,
# to,
# in,
# for]
#
# **nltk.download('punkt')**
# - This downloads the Punkt sentence tokenizer model.
# - NLTK doesn't simply split text at spaces or periods. It uses a trained model that understands punctuation.
#
# **nltk.download('punkt_tab')**
# - Starting with newer versions of NLTK (3.9+), the Punkt tokenizer was reorganized internally. Some tokenizer data is now stored in a separate resource called punkt_tab.
# - It contains internal tables used by the tokenizer, such as language-specific abbreviation and tokenization data.

# %%
text = "The quick brown fox jumps over the lazy dog"
tokens = word_tokenize(text.lower())
tokens
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %% [markdown]
# #### Remove Stop Words
# - Loads the English stopword list using *stopwords.words('english').*
# - Filters out the stop words from the tokenized text using list comprehension.
# - Prints both the original tokens and the filtered tokens for comparison.

# %%
stop_word = set(stopwords.words('english'))
print(stop_word) # Disply comman engilsh stop word
# Out:
# {'what', 'd', 'being', "he's", 'because', 'of', 'now', 're', 'was', 'your', "they're", 'then', "he'd", "he'll", 'aren', 'his', 'i', 'in', 'can', 'or', 'this', 'we', 'been', 'when', 'haven', 'once', 'too', 'were', 'most', 'yours', 'about', 'having', "it'd", "i've", 'doing', "that'll", "should've", 've', "i'd", 'very', 'to', 'on', 'so', 'each', 'll', "won't", 'isn', 'won', 'hers', 'them', 'again', 'shouldn', 'o', 'until', 'should', "shouldn't", 'why', 'you', 'm', 'own', "she'd", 'after', 'it', 'which', 'me', 'there', "couldn't", 'against', 'ma', 'same', "needn't", "mustn't", 'up', 'wouldn', 'into', 'yourself', 'theirs', "we'd", 'they', 'is', 'not', 'am', 'both', "doesn't", 'him', "they've", 'ourselves', 'our', 'ain', 'any', "mightn't", "weren't", 'with', 'didn', 'do', 'other', 'nor', 'only', "shan't", 'those', 'down', 'myself', 'has', 'where', 'weren', 'all', 'over', 'under', 'between', 'wasn', 'needn', "it's", 'during', 'off', "she'll", 'an', 'whom', 'doesn', "they'd", 'further', "are
# ...

# %%
fliterd_Word = [word for word in tokens if word not in stop_word]
fliterd_Word
# Out:
# ['quick', 'brown', 'fox', 'jumps', 'lazy', 'dog']

# %% [markdown]
# ### Custom Stop Words with NLTK

# %% [markdown]
# ### Step 1: Create Custom Stopwords
# - Imports the Counter class to count the frequency of words in the text.
# - Combines multiple text samples into a single list of tokens.
# - Identifies frequently occurring words (frequency ≥ 3) and stores them as custom stop words

# %%
from collections import Counter

text_data = [
    "data science is growing fast",
    "data analysis is important in science",
    "science and data are related"
]

all_tokens = " ".join(text_data).lower().split()
print("Tokens :- ",all_tokens)

freq = Counter(all_tokens)

print("Frquency Of Tokens:- ",freq)
custom_stopwords = set([word for word, count in freq.items() if count >= 3])

print("Custom StopWord :- ",custom_stopwords)
# Out:
# Tokens :-  ['data', 'science', 'is', 'growing', 'fast', 'data', 'analysis', 'is', 'important', 'in', 'science', 'science', 'and', 'data', 'are', 'related']
# Frquency Of Tokens:-  Counter({'data': 3, 'science': 3, 'is': 2, 'growing': 1, 'fast': 1, 'analysis': 1, 'important': 1, 'in': 1, 'and': 1, 'are': 1, 'related': 1})
# Custom StopWord :-  {'data', 'science'}
