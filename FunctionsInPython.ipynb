# %%
def hello():  # function without Argument
    print("Hello Boss")
hello()
# Out:
# Hello Boss

# %%
def add(x,y): # x,y is called formal argument  
    c =  x+y;
    return c;
add(10,20) # 10,20 is called actual argument
# Out:
# 30

# %%
def add(x,y): # x,y is called formal argument  
    c =  x+y;
    return c;
add(10) # 10,20 is called actual argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2     c =  x+y;
#       3     return c;
# ----> 4 add(10) # 10,20 is called actual argument
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
def add(x,y): 
    c =  x+y;
    print(c);
print(add(10,20))
print(type(add(10,20)) )
# Out:
# 30
# None
# 30
# <class 'NoneType'>

# %%
def add(x,y): 
    c =  x+y;
    return c;
print(add(10,20))
print(type(add(10,20)))
# Out:
# 30
# <class 'int'>
