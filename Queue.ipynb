# %%
from collections import
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from collections import Queue
#
# ImportError: cannot import name 'Queue' from 'collections' (C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\collections\__init__.py)
