# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Dataset
seasons = ["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"]
sdict = {"2010":0,"2011":1,"2012":2,"2013":3,"2014":4,"2015":5,"2016":6,"2017":7,"2018":8,"2019":9}

# Players 
players = ["sachin","rahul","smith","sami","pollerd","morris","samson","dhoni","kholi","sky"]
pdict = {"sachin":0,"rahul":1,"smith":2,"sami":3,"pollerd":4,"morris":5,"samson":6,"dhoni":7,"kholi":8,"sky":9}

# Salaries 
sachin_salaries = [15946875,17718750,19490625,21262500,23034375,24806250,25244493,27849149,30454805,23500000]
rahul_salaries = [12000000,12744189,13488377,14232567,14976754,16324500,18038573,19752645,21466718,23180790]
smith_salaries = [4621800,5828090,13041250,14410481,15779912,14500000,16022500,17545000,19067500,20644400]
sami_salaries = [3713640,4694041,13041250,14410481,15779912,17149243,18518574,19450000,22407474,22458000]
pollerd_salaries = [4493160,4806720,6061274,13758000,15202590,16647180,18091770,19536360,20513178,21436271]
morris_salaries = [3348000,4235220,12455000,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
samson_salaries = [3144240,3380160,3615960,4574189,13520500,14940153,16359805,17779458,18668431,20068563]
dhoni_salaries = [0,0,4171200,4484040,4796880,6053663,15506632,16669630,17832627,18995624]
kholi_salaries = [0,0,0,4822800,5184480,5546160,6993708,16402500,17632688,18862875]
sky_salaries = [3031920,3841443,13041250,14410581,15779912,14200000,15691000,17182000,18673000,15000000]

# Matrix 
salary = np.array([sachin_salaries,rahul_salaries,smith_salaries,sami_salaries,pollerd_salaries,morris_salaries,samson_salaries,dhoni_salaries,kholi_salaries,sky_salaries])

# Games
sachin_g =  [80,77,82,82,73,82,58,78,6,35]
rahul_g =   [82,57,82,79,76,72,60,72,79,80]
smith_g =   [79,78,75,81,76,79,62,76,77,69]
sami_g =    [80,65,77,66,69,77,55,67,77,40]
pollerd_g = [82,82,82,79,82,78,54,76,71,41]
morris_g =  [70,69,67,77,70,77,57,74,79,44]
samson_g =  [78,64,80,78,45,80,60,70,62,82]
dhoni_g =   [35,35,80,74,82,78,66,81,81,27]
kholi_g =   [40,40,40,81,78,81,39,0,10,51]
sky_g =     [75,51,51,79,77,76,49,69,54,62]

# Matrix 
games = np.array([sachin_g,rahul_g,smith_g,sami_g,pollerd_g,morris_g,samson_g,dhoni_g,kholi_g,sky_g])

# Points
sachin_pts =     [2832,2430,2323,2201,1970,2078,1616,2133,83,782]
rahul_pts =      [1653,1426,1779,1688,1619,1312,1129,1170,1245,1154]
smith_pts =      [2478,2132,2250,2304,2258,2111,1683,2036,2089,1743]
sami_pts =       [2122,1881,1978,1504,1943,1970,1245,1920,2112,966]
pollerd_pts =    [1292,1443,1695,1624,1503,1784,1113,1296,1297,646]
morris_pts =     [1572,1561,1496,1746,1678,1438,1025,1232,1281,928]
samson_pts =     [1258,1104,1684,1781,841,1268,1189,1186,1185,1564]
dhoni_pts =      [903,903,1624,1871,2472,2161,1850,2280,2593,686]
kholi_pts =      [597,597,597,1361,1619,2026,852,0,159,904]
sky_pts =        [2040,1397,1254,2386,2045,1941,1082,1463,1028,1331]

# Matrix
points = np.array([sachin_pts,rahul_pts,smith_pts,sami_pts,pollerd_pts,morris_pts,samson_pts,dhoni_pts,kholi_pts,sky_pts])

# %%
games
# Out:
# array([[80, 77, 82, 82, 73, 82, 58, 78,  6, 35],
#        [82, 57, 82, 79, 76, 72, 60, 72, 79, 80],
#        [79, 78, 75, 81, 76, 79, 62, 76, 77, 69],
#        [80, 65, 77, 66, 69, 77, 55, 67, 77, 40],
#        [82, 82, 82, 79, 82, 78, 54, 76, 71, 41],
#        [70, 69, 67, 77, 70, 77, 57, 74, 79, 44],
#        [78, 64, 80, 78, 45, 80, 60, 70, 62, 82],
#        [35, 35, 80, 74, 82, 78, 66, 81, 81, 27],
#        [40, 40, 40, 81, 78, 81, 39,  0, 10, 51],
#        [75, 51, 51, 79, 77, 76, 49, 69, 54, 62]])

# %%
salary
# Out:
# array([[15946875, 17718750, 19490625, 21262500, 23034375, 24806250,
#         25244493, 27849149, 30454805, 23500000],
#        [12000000, 12744189, 13488377, 14232567, 14976754, 16324500,
#         18038573, 19752645, 21466718, 23180790],
#        [ 4621800,  5828090, 13041250, 14410481, 15779912, 14500000,
#         16022500, 17545000, 19067500, 20644400],
#        [ 3713640,  4694041, 13041250, 14410481, 15779912, 17149243,
#         18518574, 19450000, 22407474, 22458000],
#        [ 4493160,  4806720,  6061274, 13758000, 15202590, 16647180,
#         18091770, 19536360, 20513178, 21436271],
#        [ 3348000,  4235220, 12455000, 14410581, 15779912, 14500000,
#         16022500, 17545000, 19067500, 20644400],
#        [ 3144240,  3380160,  3615960,  4574189, 13520500, 14940153,
#         16359805, 17779458, 18668431, 20068563],
#        [       0,        0,  4171200,  4484040,  4796880,  6053663,
#         15506632, 16669630, 17832627, 18995624],
# ...

# %%
pdict
# Out:
# {'sachin': 0,
#  'rahul': 1,
#  'smith': 2,
#  'sami': 3,
#  'pollerd': 4,
#  'morris': 5,
#  'samson': 6,
#  'dhoni': 7,
#  'kholi': 8,
#  'sky': 9}

# %%
sdict
# Out:
# {'2010': 0,
#  '2011': 1,
#  '2012': 2,
#  '2013': 3,
#  '2014': 4,
#  '2015': 5,
#  '2016': 6,
#  '2017': 7,
#  '2018': 8,
#  '2019': 9}

# %%
salary//games
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14656\3291110966.py:1: RuntimeWarning: divide by zero encountered in floor_divide
#   salary//games
# array([[ 199335,  230113,  237690,  259298,  315539,  302515,  435249,
#          357040, 5075800,  671428],
#        [ 146341,  223582,  164492,  180159,  197062,  226729,  300642,
#          274342,  271730,  289759],
#        [  58503,   74719,  173883,  177907,  207630,  183544,  258427,
#          230855,  247629,  299194],
#        [  46420,   72216,  169366,  218340,  228694,  222717,  336701,
#          290298,  291006,  561450],
#        [  54794,   58618,   73917,  174151,  185397,  213425,  335032,
#          257057,  288918,  522835],
#        [  47828,   61380,  185895,  187150,  225427,  188311,  281096,
#          237094,  241360,  469190],
#        [  40310,   52815,   45199,   58643,  300455,  186751,  272663,
#          253992,  301103,  244738],
#        [      0,       0,   52140,   60595,   58498,   77611,  234948,
# ...

# %%
np.round(salary//games)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14656\4138143268.py:1: RuntimeWarning: divide by zero encountered in floor_divide
#   np.round(salary//games)
# array([[ 199335,  230113,  237690,  259298,  315539,  302515,  435249,
#          357040, 5075800,  671428],
#        [ 146341,  223582,  164492,  180159,  197062,  226729,  300642,
#          274342,  271730,  289759],
#        [  58503,   74719,  173883,  177907,  207630,  183544,  258427,
#          230855,  247629,  299194],
#        [  46420,   72216,  169366,  218340,  228694,  222717,  336701,
#          290298,  291006,  561450],
#        [  54794,   58618,   73917,  174151,  185397,  213425,  335032,
#          257057,  288918,  522835],
#        [  47828,   61380,  185895,  187150,  225427,  188311,  281096,
#          237094,  241360,  469190],
#        [  40310,   52815,   45199,   58643,  300455,  186751,  272663,
#          253992,  301103,  244738],
# ...

# %%
salary[0]
# Out:
# array([15946875, 17718750, 19490625, 21262500, 23034375, 24806250,
#        25244493, 27849149, 30454805, 23500000])

# %%
plt.plot(salary[0])

# %% [markdown]
# ##### In First Graph Their
#  - x-axis reprsented player session Years 0:2010,1:2011,...,9:2019
#  - y-axis reprsented player salary folting values apperoximatily 1.5 --> 1500000
#
# ##### Insight are
#  - 1st player salary will increases till 2018 . but in 2019 session salary will dcrease
#
# ##### client ask - why Dcrease Salary ?
# - show the number of game played by player. player 1st will play after 2017 only 6 games in 2018 and next session just 35 that why it dcrease the salery

# %%
games[0]
# Out:
# array([80, 77, 82, 82, 73, 82, 58, 78,  6, 35])

# %% [markdown]
# #### We add Paramater To the graph behavior will change, color will be chnage
#
# - plot(x, y, 'go--', linewidth=2, markersize=12)
# - plot(x, y, color='green', marker='o', linestyle='dashed',
#   ...      linewidth=2, markersize=12)
#
#   *Properties:*
#     - agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#     - alpha: float or None
#     - animated: bool
#     - antialiased or aa: bool
#     - clip_box: `~matplotlib.transforms.BboxBase` or None
#     - clip_on: bool
#     - clip_path: Patch or (Path, Transform) or None
#     - color or c: :mpltype:`color`
#     - dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#     - dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#     - dashes: sequence of floats (on/off ink in points) or (None, None)
#     - data: (2, N) array or two 1D arrays
#     - drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#     - figure: `~matplotlib.figure.Figure` or `~matplotlib.figure.SubFigure`
#     - fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#     - gapcolor: :mpltype:`color` or None
#     - gid: str
#     - in_layout: bool
#     - label: object
#     - linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#     - linewidth or lw: float
#     - marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#     - markeredgecolor or mec: :mpltype:`color`
#     - markeredgewidth or mew: float
#     - markerfacecolor or mfc: :mpltype:`color`
#     - markerfacecoloralt or mfcalt: :mpltype:`color`
#     - markersize or ms: float
#     - markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#     - mouseover: bool
#     - path_effects: list of `.AbstractPathEffect`
#     - picker: float or callable[[Artist, Event], tuple[bool, dict]]
#     - pickradius: float
#     - rasterized: bool
#     - sketch_params: (scale: float, length: float, randomness: float)
#     - snap: bool or None
#     - solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#     - solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#     - transform: unknown
#     - url: str
#     - visible: bool
#     - xdata: 1D array
#     - ydata: 1D array
#     - zorder: float
#
# **Markers**
#
#
# | character     |  description                      |
# | ------------: | --------------------------------: |
# | ``'.'``       | point marker                      |
# | ``','``       |  pixel marker                     |
# | ``'o'``       |  circle marker                    |
# | ``'v'``       |  triangle_down marker             |
# | ``'^'``       |  triangle_up marker               |
# | ``'<'``       |  triangle_left marker             |
# | ``'>'``       |  triangle_right marker            |
# | ``'1'``       |  tri_down marker                  |
# | ``'2'``       |  tri_up marker                    |
# | ``'3'``       |  tri_left marker                  |
# | ``'4'``       |  tri_right marker                 |
# | ``'8'``       |  octagon marker                   |
# | ``'s'``       |  square marker                    |
# | ``'p'``       |  pentagon marker                  |
# | ``'P'``       |  plus (filled) marker             |
# | ``'*'``       |  star marker                      |
# | ``'h'``       |  hexagon1 marker                  |
# | ``'H'``       |  hexagon2 marker                  |
# | ``'+'``       |  plus marker                      |
# | ``'x'``       |  x marker                         |
# | ``'X'``       |  x (filled) marker                |
# | ``'D'``       |  diamond marker                   |
# | ``'d'``       |  thin_diamond marker              |
# | ``'|'``       |  vline marker                     |
# | ``'_'``       |  hline marker                     |
#
# **Line Styles**
#
#
# | character |       description       |
# | ----------:| -----------------------: |
# | ``'-'``   |       solid line style |
# | ``'--'``  |       dashed line style  |
# | ``'-.'``  |       dash-dot line style  |
# | ``':'``   |point marker       dotted line style |
#
# Example format strings::
#
#     -  'b'   :  # blue markers with default shape
#     -  'or'  :  # red circles
#     -  '-g'  :  # green solid line
#     -  '--'  :  # dashed line with default color
#     -  '^k:' :  # black triangle_up markers connected by a dotted line
#
# **Colors**
#
# The supported color abbreviations are the single letter codes
#
#
# | character    |    color  |
# |--------------:|-----------:|
# | ``'b'``      |    blue   |
# | ``'g'``      |    green  |
# | ``'r'``      |    red    |
# | ``'c'``      |    cyan   |
# | ``'m'``      |    magenta|
# | ``'y'``      |    yellow |
# | ``'k'``      |    black  |
# | ``'w'``      |    white  |

# %%
plt.plot(salary[0],color="green")

# %%
plt.plot(salary[0],c="r")

# %%
plt.plot(salary[0],c="m")

# %%
plt.plot(salary[0],color="green",marker="s")

# %%
plt.plot(salary[0],color="green",marker="s",markersize=10)

# %%
plt.plot(salary[0],c="r",marker='o',ms=15)

# %%
plt.plot(salary[0],c="g",ls='--',marker='d',ms=8)

# %%
plt.plot(salary[0],c="g",ls='-.',marker='D',ms=8)

# %%
plt.plot(salary[0],c="m",ls=':',marker='d',ms=8)

# %%
plt.plot(salary[0],c="r",ls='--',marker='H',ms=8)

# %%
plt.plot(salary[0],c="r",ls='--',lw=4,marker='d',ms=12)

# %%
plt.plot(salary[0],c="r",ls='--',lw=4,marker='h',ms=12)

# %%
plt.plot(salary[0],c="r",ls=':',lw=4,marker='1',ms=12)

# %%
plt.plot(salary[0],c="r",ls='--',lw=4,marker='2',ms=12)

# %%
sdict
# Out:
# {'2010': 0,
#  '2011': 1,
#  '2012': 2,
#  '2013': 3,
#  '2014': 4,
#  '2015': 5,
#  '2016': 6,
#  '2017': 7,
#  '2018': 8,
#  '2019': 9}

# %% [markdown]
# ## # We Fill The X-axis of graph by using the xticks() method
#
# Examples
# --------
#
# - locs, labels = xticks()  # Get the current locations and labels.
# - xticks(np.arange(0, 1, step=0.2))  # Set label locations.
# - xticks(np.arange(3), ['Tom', 'Dick', 'Sue'])  # Set text labels.
# - xticks([0, 1, 2], ['January', 'February', 'March'],
# ...        rotation=20)  # Set text labels and properties.
# - xticks([])  # Disable xticks.

# %%
plt.plot(salary[0],c="g",ls='-',lw=1,marker='s',ms=8)
plt.xticks(list(range(0,10)),seasons,rotation=10) # it is x-axis of the graph 
plt.show()

# %%
plt.plot(salary[0],c="g",ls='-',lw=1,marker='s',ms=8)
plt.xticks(list(range(0,10)),seasons,rotation='vertical') # it is x-axis of the graph 
plt.show()

# %%
plt.plot(salary[0],c="g",ls='-',lw=1,marker='s',ms=8)
plt.plot(salary[1],c="b",ls=':',lw=1,marker='o',ms=8)
# Compare Two Player Salary and show the client performance and fee paid 
plt.xticks(list(range(0,10)),seasons,rotation=15) 
plt.show()

# %%
plt.plot(salary[0],c="g",ls='-',lw=1,marker='s',ms=8)
plt.plot(salary[1],c="b",ls=':',lw=1,marker='o',ms=8)
plt.plot(salary[5],c="r",ls='-.',lw=2,marker='^',ms=8)
# Compare Three Player Salery and show the client performance and fee paid 
plt.xticks(list(range(0,10)),seasons,rotation=15) 
plt.show()

# %% [markdown]
# ### Insights
# - in this graph the player 5 salery will suddenly increase between 2011 to 2012 year
# - but in this grpah which player are which line ploted there confusion so we add,
#
# Call signatures::
#
#     legend()
#     legend(handles, labels)
#     legend(handles=handles)
#     legend(labels)
#
# The call signatures correspond to the following different ways to use
# this method:
#
# **1. Automatic detection of elements to be shown in the legend**
#
# The elements to be added to the legend are automatically determined,
# when you do not pass in any extra arguments.
#
# In this case, the labels are taken from the artist. You can specify
# them either at artist creation or by calling the
# :meth:`~.Artist.set_label` method on the artist::
#
#     ax.plot([1, 2, 3], label='Inline label')
#     ax.legend()
#
# or::
#
#     line, = ax.plot([1, 2, 3])
#     line.set_label('Label via method')
#     ax.legend()
#
#
# **2. Explicitly listing the artists and labels in the legend**
#
# For full control of which artists have a legend entry, it is possible
# to pass an iterable of legend artists followed by an iterable of
# legend labels respectively::
#
#     ax.legend([line1, line2, line3], ['label1', 'label2', 'label3'])
#
#
# **3. Explicitly listing the artists in the legend**
#
# This is similar to 2, but the labels are taken from the artists'
# label properties. Example::
#
#     line1, = ax.plot([1, 2, 3], label='label1')
#     line2, = ax.plot([1, 2, 3], label='label2')
#     ax.legend(handles=[line1, line2])
#
#
# **4. Labeling existing plot elements**
#
# .. admonition:: Discouraged
#
#     This call signature is discouraged, because the relation between
#     plot elements and labels is only implicit by their order and can
#     easily be mixed up.
#
# To make a legend for all artists on an Axes, call this function with
# an iterable of strings, one for each legend item. For example::
#
#     ax.plot([1, 2, 3])
#     ax.plot([5, 6, 7])
#     ax.legend(['First line', 'Second line'])
#
# |    Location String  |   Location Code  |
# |    ----------------: | -----------------:|
# |    'best' (Axes only)|   0 |
# |    'upper right'     |   1 |
# |    'upper left'      |   2 |
# |    'lower left'      |   3 |
# |    'lower right'     |   4 |
# |    'right'           |   5 |
# |    'center left'     |   6 |
# |    'center right'    |   7 |
# |    'lower center'    |   8 |
# |    'upper center'    |   9 |
# |    'center'          |   10 |

# %%
plt.plot(salary[0],c="g",ls='-',lw=1,marker='s',ms=8,label=players[0])
plt.plot(salary[1],c="b",ls=':',lw=1,marker='o',ms=8,label=players[1])
plt.plot(salary[7],c="y",ls='--',lw=2,marker='^',ms=8,label=players[7])
plt.plot(salary[8],c="r",ls=':',lw=2,marker='*',ms=8,label=players[8])

plt.legend(loc="lower right",bbox_to_anchor=(1,0)) # According to need we can add the legend setting loc-> location , bbox_to_anchor --> boundery box to anchor
plt.xticks(list(range(0,10)),seasons,rotation=15) 
plt.show()

# %%
plt.plot(salary[0],c="g",ls='-',lw=1,marker='s',ms=8,label=players[0])
plt.plot(salary[1],c="b",ls=':',lw=1,marker='o',ms=8,label=players[1])
plt.plot(salary[7],c="y",ls='--',lw=2,marker='^',ms=8,label=players[7])
plt.plot(salary[8],c="r",ls=':',lw=2,marker='*',ms=8,label=players[8])
 
plt.legend() # it is also work , it just create the box of --> label=values
plt.xticks(list(range(0,10)),seasons,rotation=15) 
plt.show()

# %%
plt.plot(salary[0],c="g",ls='-',lw=1,marker='s',ms=8,label=players[0])
plt.plot(salary[1],c="b",ls=':',lw=1,marker='o',ms=8,label=players[1])
plt.plot(salary[2],c="y",ls='--',lw=2,marker='^',ms=8,label=players[2])
plt.plot(salary[3],c="r",ls=':',lw=2,marker='*',ms=8,label=players[3])
plt.plot(salary[4],c="g",ls='-',lw=1,marker='s',ms=8,label=players[4])
plt.plot(salary[5],c="b",ls=':',lw=1,marker='o',ms=8,label=players[5])
plt.plot(salary[6],c="y",ls='--',lw=2,marker='^',ms=8,label=players[6])
plt.plot(salary[7],c="r",ls=':',lw=2,marker='*',ms=8,label=players[7])
plt.plot(salary[8],c="g",ls='-',lw=1,marker='s',ms=8,label=players[8])
plt.plot(salary[9],c="b",ls=':',lw=1,marker='o',ms=8,label=players[9])

plt.legend() # it is also work , it just create the box of --> label=values
plt.xticks(list(range(0,10)),seasons,rotation=15) 
plt.show()

# %% [markdown]
# - look at the grpah, very pooer to understand
# - thst why we introduce the Power Bi and Tableues Tools. To make much better understanding
# - we can also not make dashborad

# %%
plt.plot(salary[0],c="g",ls='-',lw=1,marker='s',ms=8,label=players[0])
plt.plot(salary[1],c="b",ls=':',lw=1,marker='o',ms=8,label=players[1])
plt.plot(salary[2],c="y",ls='--',lw=2,marker='^',ms=8,label=players[2])
plt.plot(salary[3],c="r",ls=':',lw=2,marker='*',ms=8,label=players[3])
plt.plot(salary[4],c="g",ls='-',lw=1,marker='s',ms=8,label=players[4])
plt.plot(salary[5],c="b",ls=':',lw=1,marker='o',ms=8,label=players[5])
plt.plot(salary[6],c="y",ls='--',lw=2,marker='^',ms=8,label=players[6])
plt.plot(salary[7],c="r",ls=':',lw=2,marker='*',ms=8,label=players[7])
plt.plot(salary[8],c="g",ls='-',lw=1,marker='s',ms=8,label=players[8])
plt.plot(salary[9],c="b",ls=':',lw=1,marker='o',ms=8,label=players[9])

plt.legend() # it is also work , it just create the box of --> label=values
plt.xticks(list(range(0,10)),seasons,rotation=15) 
plt.show()
